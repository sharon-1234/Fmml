# %% [markdown]
# <a href="https://colab.research.google.com/github/sharon-1234/Fmml/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-29 02:00:48--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   291MB/s    in 0.2s
#
# 2024-03-29 02:00:48 (291 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6530   1703.00994v1  This paper presents a new multitask learning f...  stat
# 9332    1206.5754v6  Gaussian processes (GP) are powerful tools for...  stat
# 25870  1512.01722v4  To investigate whether the vanishing point (VP...    cs
# 29811  1710.07161v1  Automatic visual speech recognition is an inte...    cs
# 32040   1406.1385v1  Information divergence that measures the diffe...    cs
# ...             ...                                                ...   ...
# 36559  1503.02834v1  We study sequential decision making in environ...  stat
# 10215  1802.00420v2  We identify obfuscated gradients, a kind of gr...    cs
# 828    1706.02275v3  We explore deep reinforcement learning methods...    cs
# 34139   1403.5596v1  Matching texts in highly inflected languages s...    cs
# 22546  1611.03531v2  The vision for precision medicine is to use in...  stat
#
#                                                    title  year  \
# 6530                Co-Clustering for Multitask Learning  2017
# 9332   Bayesian Modeling with Gaussian Processes usin...  2012
# 25870  Vanishing point attracts gaze in free-viewing ...  2015
# 29811  Visual Speech Recognition Using PCA Networks a...  2017
# 32040                Learning the Information Divergence  2014
# ...                                                  ...   ...
# 36559   Doubly Robust Policy Evaluation and Optimization  2015
# 10215  Obfuscated Gradients Give a False Sense of Sec...  2018
# 828    Multi-Agent Actor-Critic for Mixed Cooperative...  2017
# 34139  A Lemma Based Evaluator for Semitic Language T...  2014
# 22546  Estimating Dynamic Treatment Regimes in Mobile...  2016
#
#                                                 keywords
# 6530   [multitask, framework, representation, incorpo...
# 9332   [processes, probabilistic, distributions, func...
# 25870  [investigate, vanishing, significant, experime...
# 29811  [automatic, recognition, interesting, recognit...
# 32040  [information, divergence, difference, nonnegat...
# ...                                                  ...
# 36559  [sequential, environments, partially, contextu...
# 10215  [obfuscated, gradients, phenomenon, adversaria...
# 828    [reinforcement, analyzing, difficulty, traditi...
# 34139  [inflected, languages, automatic, technique, i...
# 22546  [precision, individual, characteristics, perso...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6530     [multitask, framework, representation, incorpo...
# 9332     [processes, probabilistic, distributions, func...
# 25870    [investigate, vanishing, significant, experime...
# 29811    [automatic, recognition, interesting, recognit...
# 32040    [information, divergence, difference, nonnegat...
#                                ...
# 21969    [inference, regression, intractable, expectati...
# 12287    [sequential, probabilistic, interpretable, com...
# 21838    [inferring, strengths, historical, estimates, ...
# 29029    [discrepancy, polarimetric, recognition, chall...
# 507      [supervised, embedding, disparate, functions, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8883 words.
# Out of those 4586 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f951f7fd-6ba1-4b75-92be-763e7b19ad0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f951f7fd-6ba1-4b75-92be-763e7b19ad0a")) {                    Plotly.newPlot(                        "f951f7fd-6ba1-4b75-92be-763e7b19ad0a",                        [{"x":["incorporating","generally","equations","clustering","restricted","generalized","derivation","outperforms","relationships","representation","synthetic","multitask","algorithm","systematically","experimental","benchmark","effectively","conjugate","framework","implicitly","processes","properties","covariance","variability","theoretical","distributions","demonstrate","practical","computational","versatile","implementation","functions","evaluating","assessment","approximations","determine","approximating","inference","collection","attractive","probabilistic","compatible","conducted","hierarchical","smoothness","posterior","challenges","character","consisted","vanishing","containing","probability","presentation","significant","direction","locations","attention","experiment","confounding","investigate","significantly","observers","experiments","hypothesis","fixations","imaginary","recurrent","utterance","respectively","component","convolutional","histograms","techniques","especially","principle","recognition","interesting","unsupervised","spatiotemporal","correctness","challenging","available","automatic","outperformed","validation","information","extracted","divergence","reformulate","matrixtensor","factorization","optimization","stochastic","likelihood","selecting","distribution","difference","divergences","facilitates","different","suggested","nonnegative","approximated","embedding","connections","furthermore","selection","estimation","accurately","objective","separable","correlation","supervised","effortlessly","manifestations","automating","environment","dependence","theoretic","characterized","multivariate","translated","supervision","including","explanation","representations","ambiguous","redundancy","successes","engineering","engineered","experience","algorithms","empirical","achieving","applications","objectives","involvement","minimization","decisions","predictive","sufficient","dichotomy","foundational","particular","difficult","definition","strategies","therefore","increasingly","minimizing","influencing","prediction","important","interpretability","completely","causality","dimensions","epistemic","procedural","involving","uncertainty","statistical","interacting","comparing","additionally","effectiveness","associated","coefficients","operators","parametrization","exponential","generalize","exploding","preserving","baselines","outperforming","transition","arbitrary","dimensional","correspondence","challenge","connected","formulations","connection","efficiently","dependency","approximation","formulation","expressive","limitations","generative","interactions","primarily","conventional","improvement","capability","simplistic","directions","structure"],"y":[76,71,32,113,53,82,14,252,67,390,138,7,835,26,376,203,117,7,564,15,92,220,21,20,150,109,530,125,268,7,126,197,71,52,32,78,18,228,69,27,176,16,74,94,17,40,114,61,3,11,56,196,10,246,69,39,170,87,2,162,291,13,598,55,9,3,139,9,82,90,378,7,396,118,51,351,76,148,17,11,276,320,193,13,51,708,124,31,13,1,34,305,105,69,48,225,74,7,13,690,28,8,31,101,47,172,159,200,75,173,10,66,194,1,1,9,115,20,45,32,26,15,43,219,22,243,20,17,7,48,12,39,603,154,83,436,27,1,61,68,66,81,1,3,282,163,45,96,141,51,38,2,229,373,21,42,7,39,13,6,37,93,165,14,78,58,203,109,43,43,7,51,62,2,53,64,31,40,78,192,27,152,64,23,42,145,36,122,67,43,53,106,76,22,111,151,54,5,40,305],"type":"bar"},{"x":["incorporating","generally","equations","clustering","rest ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4586,), (4586, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.795

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Use</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.35260115606936404);'>Knowledge</span> <span style=''>Graph</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>Rescoring</span> <span style=''>the</span> <span style=''>N</span> <span style=''>Best</span> <span style=''>List</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.5950413223140496);'>Automatic</span> <span style=''>Speech</span> <span style='background-color:rgba(0, 255, 0, 0.5990888382687927);'>Recognition</span> <br/><br/><span style=''>With</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>evolution</span> <span style=''>of</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>based</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.5950413223140496);'>automatic</span> <span style=''>speech</span> <span style='background-color:rgba(0, 255, 0, 0.5990888382687927);'>recognition</span> <span style=''>(ASR)</span> <span style=''>field</span> <span style=''>has</span> <span style=''>been</span> <span style=''>advanced</span> <span style=''>to</span> <span style=''>a</span> <span style=''>level</span> <span style=''>where</span> <span style=''>building</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>with</span> <span style=''>speech</span> <span style='background-color:rgba(0, 255, 0, 0.5238095238095237);'>interface</span> <span style=''>is</span> <span style=''>a</span> <span style=''>reality</span> <span style=''>In</span> <span style=''>spite</span> <span style=''>of</span> <span style=''>these</span> <span style=''>advances</span> <span style=''>building</span> <span style=''>a</span> <span style=''>real</span> <span style=''>time</span> <span style=''>speech</span> <span style=''>recogniser</span> <span style=''>faces</span> <span style=''>several</span> <span style=''>problems</span> <span style=''>such</span> <span style=''>as</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.5990888382687927);'>recognition</span> <span style=''>accuracy</span> <span style=''>domain</span> <span style='background-color:rgba(0, 255, 0, 0.44785276073619634);'>constraint</span> <span style=''>and</span> <span style=''>out</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6400000000000001);'>vocabulary</span> <span style=''>words</span> <span style=''>The</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.5990888382687927);'>recognition</span> <span style=''>accuracy</span> <span style=''>problem</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3114754098360655);'>addressed</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.32484076433121023);'>improving</span> <span style=''>the</span> <span style=''>acoustic</span> <span style=''>model</span> <span style=''>language</span> <span style=''>model</span> <span style=''>decoder</span> <span style=''>and</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>rescoring</span> <span style=''>the</span> <span style=''>N</span> <span style=''>best</span> <span style=''>list</span> <span style=''>at</span> <span style=''>the</span> <span style=''>output</span> <span style=''>of</span> <span style=''>the</span> <span style=''>decoder</span> <span style=''>We</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.44144144144144143);'>considering</span> <span style=''>the</span> <span style=''>N</span> <span style=''>best</span> <span style=''>list</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>rescoring</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>improve</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <span style=''>via</span> <span style=''>Chaining</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>under</span> <span style=''>a</span> <span style=''>bandit</span> <span style=''>feedback</span> <span style=''>model</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalize</span> <span style=''>the</span> <span style=''>GP</span> <span style=''>UCB</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>Srinivas</span> <span style=''>and</span> <span style=''>al</span> <span style=''>2012</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style=''>kernels</span> <span style=''>and</span> <span style=''>search</span> <span style=''>spaces</span> <span style=''>To</span> <span style=''>do</span> <span style=''>so</span> <span style=''>we</span> <span style=''>use</span> <span style=''>a</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>localized</span> <span style=''>chaining</span> <span style=''>to</span> <span style=''>control</span> <span style=''>the</span> <span style=''>supremum</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>and</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>scheme</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>of</span> <span style=''>covering</span> <span style=''>numbers</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>bounds</span> <span style=''>we</span> <span style=''>obtain</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cumulative</span> <span style=''>regret</span> <span style=''>are</span> <span style=''>more</span> <span style=''>generic</span> <span style=''>and</span> <span style=''>present</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>rates</span> <span style=''>as</span> <span style=''>the</span> <span style=''>GP</span> <span style=''>UCB</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>Finally</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>than</span> <span style=''>its</span> <span style=''>natural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitors</span> <span style=''>on</span> <span style=''>simple</span> <span style=''>and</span> <span style=''>complex</span> <span style=''>input</span> <span style=''>spaces</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Exponential</span> <span style=''>Natural</span> <span style=''>Particle</span> <span style=''>Filter</span> <br/><br/><span style=''>Particle</span> <span style=''>Filter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>(PF)</span> <span style=''>suffers</span> <span style=''>from</span> <span style=''>some</span> <span style=''>problems</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>loss</span> <span style=''>of</span> <span style=''>particle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diversity</span> <span style=''>the</span> <span style=''>need</span> <span style=''>for</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particles</span> <span style=''>and</span> <span style=''>the</span> <span style=''>costly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>density</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Exponential</span> <span style=''>Natural</span> <span style=''>Particle</span> <span style=''>Filter</span> <span style=''>(xNPF)</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>the</span> <span style=''>above</span> <span style=''>problems</span> <span style=''>In</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>a</span> <span style=''>state</span> <span style=''>transitional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>with</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>natural</span> <span style=''>gradient</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>which</span> <span style=''>balances</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploration</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploitation</span> <span style=''>more</span> <span style=''>robustly</span> <span style=''>The</span> <span style=''>results</span> <span style=''>show</span> <span style=''>that</span> <span style=''>xNPF</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>converges</span> <span style=''>much</span> <span style=''>closer</span> <span style=''>to</span> <span style=''>the</span> <span style=''>true</span> <span style=''>target</span> <span style=''>states</span> <span style=''>than</span> <span style=''>the</span> <span style=''>other</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>particle</span> <span style=''>filter</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sentiment</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>Singapore</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Presidential</span> <span style=''>Election</span> <span style=''>2011</span> <span style=''>using</span> <span style=''>Twitter</span> <span style=''>data</span> <span style=''>with</span> <span style=''>census</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correction</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Sentiment</span> <span style=''>analysis</span> <span style=''>is</span> <span style=''>a</span> <span style=''>new</span> <span style=''>area</span> <span style=''>in</span> <span style=''>text</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytics</span> <span style=''>where</span> <span style=''>it</span> <span style=''>focuses</span> <span style=''>on</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>of</span> <span style=''>the</span> <span style=''>emotions</span> <span style=''>from</span> <span style=''>the</span> <span style=''>text</span> <span style=''>patterns</span> <span style=''>This</span> <span style=''>new</span> <span style=''>form</span> <span style=''>of</span> <span style=''>analysis</span> <span style=''>has</span> <span style=''>been</span> <span style=''>widely</span> <span style=''>adopted</span> <span style=''>in</span> <span style=''>customer</span> <span style=''>relation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>management</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complaint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>management</span> <span style=''>With</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style=''>level</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technology</span> <span style=''>more</span> <span style=''>and</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>companies</span> <span style=''>are</span> <span style=''>adopting</span> <span style=''>it</span> <span style=''>and</span> <span style=''>using</span> <span style=''>it</span> <span style=''>to</span> <span style=''>champion</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>marketing</span> <span style=''>efforts</span> <span style=''>However</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sentiment</span> <span style=''>analysis</span> <span style=''>using</span> <span style=''>twitter</span> <span style=''>has</span> <span style=''>remained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extremely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>manage</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>sampling</span> <span style=''>bias</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>will</span> <span style=''>discuss</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reweighting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conjunction</span> <s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.06858564321250889)
# 	architecture (0.0806680881307747)
# 	processing (0.09737029140014215)
# 	different (0.24520255863539445)
# 	segmentation (0.07356076759061833)
# 	representation (0.13859275053304904)
# 	information (0.2515991471215352)
# 	detection (0.12864250177683015)
# 	recognition (0.12473347547974413)
# 	convolutional (0.13432835820895522)
#
# Some Statistics words are:
# 	variables (0.1339375629405841)
# 	stochastic (0.12588116817724068)
# 	statistical (0.15206445115810674)
# 	estimation (0.16666666666666666)
# 	algorithm (0.3942598187311178)
# 	distribution (0.18026183282980865)
# 	theoretical (0.15861027190332327)
# 	inference (0.20493454179254783)
# 	dimensional (0.19838872104733132)
# 	regression (0.17472306143001007)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e72a3146-3076-4951-9d7c-b53d7233ee38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e72a3146-3076-4951-9d7c-b53d7233ee38")) {                    Plotly.newPlot(                        "e72a3146-3076-4951-9d7c-b53d7233ee38",                        [{"x":["incorporating","generally","equations","clustering","restricted","generalized","derivation","outperforms","relationships","representation","synthetic","multitask","algorithm","systematically","experimental","benchmark","effectively","conjugate","framework","implicitly","processes","properties","covariance","variability","theoretical","distributions","demonstrate","practical","computational","versatile","implementation","functions","evaluating","assessment","approximations","determine","approximating","inference","collection","attractive","probabilistic","compatible","conducted","hierarchical","smoothness","posterior","challenges","character","consisted","vanishing","containing","probability","presentation","significant","direction","locations","attention","experiment","confounding","investigate","significantly","observers","experiments","hypothesis","fixations","imaginary","recurrent","utterance","respectively","component","convolutional","histograms","techniques","especially","principle","recognition","interesting","unsupervised","spatiotemporal","correctness","challenging","available","automatic","outperformed","validation","information","extracted","divergence","reformulate","matrixtensor","factorization","optimization","stochastic","likelihood","selecting","distribution","difference","divergences","facilitates","different","suggested","nonnegative","approximated","embedding","connections","furthermore","selection","estimation","accurately","objective","separable","correlation","supervised","effortlessly","manifestations","automating","environment","dependence","theoretic","characterized","multivariate","translated","supervision","including","explanation","representations","ambiguous","redundancy","successes","engineering","engineered","experience","algorithms","empirical","achieving","applications","objectives","involvement","minimization","decisions","predictive","sufficient","dichotomy","foundational","particular","difficult","definition","strategies","therefore","increasingly","minimizing","influencing","prediction","important","interpretability","completely","causality","dimensions","epistemic","procedural","involving","uncertainty","statistical","interacting","comparing","additionally","effectiveness","associated","coefficients","operators","parametrization","exponential","generalize","exploding","preserving","baselines","outperforming","transition","arbitrary","dimensional","correspondence","challenge","connected","formulations","connection","efficiently","dependency","approximation","formulation","expressive","limitations","generative","interactions","primarily","conventional","improvement","capability","simplistic","directions","structure","parameterized","regressing","comprehensive","classification","encompasses","regression","heuristic","approximate","simplifying","observation","efficient","elaborate","parameters","intervals","reductions","variables","decomposed","fortunately","presented","optimized","assembled","evolution","detection","mathematical","extensive","convergence","establish","effective","introduced","programming","investigated","separability","disparity","preserved","considering","monocular","enforcing","stylization","simultaneous","occlusion","separately","integrate","incorporate","bidirectional","coherence","examination","quantitatively","consistency","qualitatively","constraint","synthesis","differential","synthesized","adversarial","add ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	uncorrelated
# 	econometrics
# 	predictivity
# 	distinguishable
# 	generically
# 	clarified
# 	identifiability
# 	affirmative
# 	minimality
# 	archetypes
# 	reconcile
# 	separators
# 	administrative
# 	spectroradiometer
# 	emphstatistical
# 	gaussianization
# 	ergodicity
# 	factorizes
# 	heteroskedastic
# 	encapsulated
# Some words which never appear in Statistics papers:
# 	consisted
# 	observers
# 	fixations
# 	utterance
# 	simplistic
# 	fortunately
# 	assembled
# 	monocular
# 	stylization
# 	illumination
# 	temporary
# 	crossover
# 	recurring
# 	satellites
# 	expecting
# 	telephony
# 	shortening
# 	celebrity
# 	conclusively
# 	transducer

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0556743873372856e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.745
